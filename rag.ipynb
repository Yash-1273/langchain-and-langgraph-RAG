# %%
from langchain_core.documents import Document


documents = [
    Document(
        page_content="Dogs are domesticated mammals known for their loyalty and intelligence. They are often used as working animals, in roles such as police work, service assistance, and herding.",
        metadata={"source": "Animal Encyclopedia", "topic": "Dogs"}
    ),
    Document(
        page_content="There are many dog breeds, each with unique traits. For example, Golden Retrievers are known for their friendly nature, while German Shepherds are known for their work ethic.",
        metadata={"source": "Dog Breeds Guide", "topic": "Dog Breeds"}
    ),
    Document(
        page_content="Cats are small, carnivorous mammals that are valued by humans for companionship and their ability to hunt pests. They are known for their independence and agility.",
        metadata={"source": "Animal Encyclopedia", "topic": "Cats"}
    ),
    Document(
        page_content="Some popular cat breeds include the Persian, known for its long hair and calm temperament, and the Siamese, recognized by its striking blue eyes and vocal nature.",
        metadata={"source": "Cat Breeds Guide", "topic": "Cat Breeds"}
    ),
    Document(
        page_content="While dogs tend to form strong social bonds and often require attention and training, cats are more solitary and low-maintenance pets, making them ideal for people with busy lifestyles.",
        metadata={"source": "Pet Behavior Insights", "topic": "Pet Comparison"}
    )
]
